# %% [markdown]
# # Introduction
#
# This notebook does not run in **binder**.
#
# The OOI data system features a "high level" data exploration and download sub-system called Data Explorer.
# Data from this system are intended to be sampled at one minute intervals. However there are some anomalies.
# This notebook tidies up Data Explorer NetCDF files. The results are cleanly sampled at a "1Min" sample spacing.

# %%
import os, sys, time, glob, warnings
from IPython.display import clear_output             # use inside loop with clear_output(wait = True) followed by print(i)
warnings.filterwarnings('ignore')
this_dir = os.getcwd()
data_dir = this_dir + '/../data'

from matplotlib import pyplot as plt
from matplotlib import colors as mplcolors
import numpy as np, pandas as pd, xarray as xr
from numpy import datetime64 as dt64, timedelta64 as td64

# convenience functions abbreviating 'datetime64' and so on
def doy(theDatetime): return 1 + int((theDatetime - dt64(str(theDatetime)[0:4] + '-01-01')) / td64(1, 'D'))
def dt64_from_doy(year, doy): return dt64(str(year) + '-01-01') + td64(doy-1, 'D')
def day_of_month_to_string(d): return str(d) if d > 9 else '0' + str(d)

print('\nJupyter Notebook running Python {}'.format(sys.version_info[0]))
# Out:
# Jupyter Notebook running Python 3

# %%
# %timeit

############################################################
# shallow profiler dive timestamp generator
############################################################
# Datasets extend over the full program from 2014 to download date Aug 2021.
# At first look they appear sampled at 1/minute but there are anomalies; 
#   so to have more confidence this code resamples them at "1Min".

def StandardizeNetCDFDataset(source_location, datafile):
    ds   = xr.open_dataset(source_location + datafile)
    ds   = ds.set_coords("time")
    ds   = ds.swap_dims({"row":"time"})
    df   = ds.to_dataframe().resample("1Min").mean()
    vals = [xr.DataArray(data=df[c], dims=['time'], coords={'time':df.index}, attrs=ds[c].attrs) for c in df.columns]
    return xr.Dataset(dict(zip(df.columns, vals)), attrs=ds.attrs)

drive_dir = '/mnt/d/'
data_root = drive_dir + '/data/data_ooi_data_explorer/'
out_root  = drive_dir + '/data/data_explorer_1Min/'
sitekeys  = ['/axb/', '/oos/', '/osb/']
framekeys = ['/profiler/', '/platform/']
n_sites   = len(sitekeys)
n_frames  = len(framekeys)

for i in range(n_sites):
    for j in range(n_frames):
        this_data_path = data_root + sitekeys[i] + framekeys[j]
        this_out_path  = out_root + sitekeys[i] + framekeys[j]
        possible_datafiles = os.listdir(this_data_path)
        datafiles = []
        for poss in possible_datafiles:
            if poss.split('.')[1] == 'nc': datafiles.append(poss)      
        for datafile in datafiles:
            ds      = StandardizeNetCDFDataset(this_data_path, datafile)
            outfile = this_out_path + datafile.split('.')[0] + '_1Min.nc'
            ds.to_netcdf(outfile)
            print(outfile, ds.time.shape[0])
# Out:
# /mnt/d//data/data_explorer_1Min//axb//profiler/axb_profiler_backscatter_1Min.nc 3608277
# /mnt/d//data/data_explorer_1Min//axb//profiler/axb_profiler_cdom_1Min.nc 3608277
# /mnt/d//data/data_explorer_1Min//axb//profiler/axb_profiler_chlora_1Min.nc 3608277
# /mnt/d//data/data_explorer_1Min//axb//profiler/axb_profiler_density_1Min.nc 3608283
# /mnt/d//data/data_explorer_1Min//axb//profiler/axb_profiler_doxygen_1Min.nc 3608283
# /mnt/d//data/data_explorer_1Min//axb//profiler/axb_profiler_nitrate_1Min.nc 3607853
# /mnt/d//data/data_explorer_1Min//axb//profiler/axb_profiler_par_1Min.nc 3598972
# /mnt/d//data/data_explorer_1Min//axb//profiler/axb_profiler_pco2_1Min.nc 3607990
# /mnt/d//data/data_explorer_1Min//axb//profiler/axb_profiler_ph_1Min.nc 3608252
# /mnt/d//data/data_explorer_1Min//axb//profiler/axb_profiler_pressure_1Min.nc 3608283
# /mnt/d//data/data_explorer_1Min//axb//profiler/axb_profiler_salinity_1Min.nc 3608283
# /mnt/d//data/data_explorer_1Min//axb//profiler/axb_profiler_spkir_1Min.nc 3608262
# /mnt/d//data/data_explorer_1Min//axb//profiler/axb_profiler_temperature_1Min.nc 3608283
# /mnt/d//data/data_explorer_1Min//axb//profiler/axb_profiler_veleast_1Min.nc 3608252
# /mnt/d//data/data_explorer_1Min//axb//profiler/axb_profiler_velnorth_1Min.nc 3608252
# /mnt/d//data/data_explorer_1Min//axb//profiler/axb_profiler_velup_1Min.nc 3608252
# /mnt/d//data/data_explorer_1Min//axb//platform/axb_platform_backscatter_1Min.nc 3616017
# /mnt/d//data/data_explorer_1Min//axb//platform/axb_platform_cdom_1Min.nc 3616017
# /mnt/d//data/data_explorer_1Min//axb//platform/axb_platform_chlora_1Min.nc 3616017
# /mnt/d//data/data_explorer_1Min//axb//platform/axb_platform_density_1Min.nc 3615533
# /mnt/d//data/data_explorer_1Min//axb//platform/axb_platform_doxygen_1Min.nc 1141957
# /mnt/d//data/data_explorer_1Min//axb//platform/axb_platform_doxygen_seawater_CTD_1Min.nc 3615533
# /mnt/d//data/data_explorer_1Min//axb//platform/axb_platform_doxygen_seawater_DO_1Min.nc 1141957
# /mnt/d//data/data_explorer_1Min//axb//platform/axb_platform_ph_1Min.nc 3615301
# /mnt/d//data/data_explorer_1Min//axb//platform/axb_platform_pressure_1Min.nc 3615533
# /mnt/d//data/data_explorer_1Min//axb//platform/axb_platform_salinity_1Min.nc 3615533
# /mnt/d//data/data_explorer_1Min//axb//platform/axb_platform_temperature_1Min.nc 3615533
# /mnt/d//data/data_explorer_1Min//oos//profiler/oos_profiler_backscatter_1Min.nc 3044356
# /mnt/d//data/data_explorer_1Min//oos//profiler/oos_profiler_cdom_1Min.nc 3044356
# /mnt/d//data/data_explorer_1Min//oos//profiler/oos_profiler_chlora_1Min.nc 3044356
# /mnt/d//data/data_explorer_1Min//oos//profiler/oos_profiler_density_1Min.nc 3041514
# /mnt/d//data/data_explorer_1Min//oos//profiler/oos_profiler_doxygen_1Min.nc 3041514
# /mnt/d//data/data_explorer_1Min//oos//profiler/oos_profiler_nitrate_1Min.nc 2651433
# /mnt/d//data/data_explorer_1Min//oos//profiler/oos_profiler_par_1Min.nc 2146644
# /mnt/d//data/data_explorer_1Min//oos//profiler/oos_profiler_pco2_1Min.nc 2651492
# /mnt/d//data/data_explorer_1Min//oos//profiler/oos_profiler_ph_1Min.nc 2651493
# /mnt/d//data/data_explorer_1Min//oos//profiler/oos_profiler_pressure_1Min.nc 3041514
# /mnt/d//data/data_explorer_1Min//oos//profiler/oos_profiler_salinity_1Min.nc 3041514
# /mnt/d//data/data_explorer_1Min//oos//profiler/oos_profiler_spkir_1Min.nc 2651651
# /mnt/d//data/data_explorer_1Min//oos//profiler/oos_profiler_temperature_1Min.nc 3041514
# /mnt/d//data/data_explorer_1Min//oos//profiler/oos_profiler_veleast_1Min.nc 2637158
# /mnt/d//data/data_explorer_1Min//oos//profiler/oos_profiler_velnorth_1Min.nc 2637158
# /mnt/d//data/data_explorer_1Min//oos//profiler/oos_profiler_velup_1Min.nc 2637158
# /mnt/d//data/data_explorer_1Min//oos//platform/oos_platform_density_1Min.nc 3081933
# /mnt/d//data/data_explorer_1Min//oos//platform/oos_platform_doxygen_CTD_1Min.nc 3081933
# /mnt/d//data/data_explorer_1Min//oos//platform/oos_platform_doxygen_DO_1Min.nc 934696
# /mnt/d//data/data_explorer_1Min//oos//platform/oos_platform_pco2_1Min.nc 3081901
# /mnt/d//data/data_explorer_1Min//oos//platform/oos_platform_ph_1Min.nc 2564761
# /mnt/d//data/data_explorer_1Min//oos//platform/oos_platform_pressure_1Min.nc 3081933
# /mnt/d//data/data_explorer_1Min//oos//platform/oos_platform_salinity_1Min.nc 3081933
# /mnt/d//data/data_explorer_1Min//oos//platform/oos_platform_temperature_1Min.nc 3081933
# /mnt/d//data/data_explorer_1Min//oos//platform/oos_platorm_doxygen_seawater_CTD_1Min.nc 3081933
# /mnt/d//data/data_explorer_1Min//oos//platform/oos_platorm_doxygen_seawater_DO_1Min.nc 934696
# /mnt/d//data/data_explorer_1Min//osb//profiler/osb_profiler_backscatter_1Min.nc 3589070
# /mnt/d//data/data_explorer_1Min//osb//profiler/osb_profiler_cdom_1Min.nc 3589070
# /mnt/d//data/data_explorer_1Min//osb//profiler/osb_profiler_chlora_1Min.nc 3589070
# /mnt/d//data/data_explorer_1Min//osb//profiler/osb_profiler_density_1Min.nc 3588595
# /mnt/d//data/data_explorer_1Min//osb//profiler/osb_profiler_doxygen_1Min.nc 3588595
# /mnt/d//data/data_explorer_1Min//osb//profiler/osb_profiler_nitrate_1Min.nc 3588431
# /mnt/d//data/data_explorer_1Min//osb//profiler/osb_profiler_par_1Min.nc 3587233
# /mnt/d//data/data_explorer_1Min//osb//profiler/osb_profiler_pco2_1Min.nc 3385920
# /mnt/d//data/data_explorer_1Min//osb//profiler/osb_profiler_ph_1Min.nc 3587184
# /mnt/d//data/data_explorer_1Min//osb//profiler/osb_profiler_pressure_1Min.nc 3588595
# /mnt/d//data/data_explorer_1Min//osb//profiler/osb_profiler_salinity_1Min.nc 3588595
# /mnt/d//data/data_explorer_1Min//osb//profiler/osb_profiler_spkir_1Min.nc 3587234
# /mnt/d//data/data_explorer_1Min//osb//profiler/osb_profiler_temperature_1Min.nc 3588595
# /mnt/d//data/data_explorer_1Min//osb//profiler/osb_profiler_veleast_1Min.nc 3588508
# /mnt/d//data/data_explorer_1Min//osb//profiler/osb_profiler_velnorth_1Min.nc 3588508
# /mnt/d//data/data_explorer_1Min//osb//profiler/osb_profiler_velup_1Min.nc 3588508
# /mnt/d//data/data_explorer_1Min//osb//platform/osb_platform_backscatter_1Min.nc 3594819
# /mnt/d//data/data_explorer_1Min//osb//platform/osb_platform_cdom_1Min.nc 3594819
# /mnt/d//data/data_explorer_1Min//osb//platform/osb_platform_chlora_1Min.nc 3594819
# /mnt/d//data/data_explorer_1Min//osb//platform/osb_platform_density_1Min.nc 3594340
# /mnt/d//data/data_explorer_1Min//osb//platform/osb_platform_doxygen_1Min.nc 3594340
# /mnt/d//data/data_explorer_1Min//osb//platform/osb_platform_doxygen_seawater_CTD_1Min.nc 3594340
# /mnt/d//data/data_explorer_1Min//osb//platform/osb_platform_doxygen_seawater_DO_1Min.nc 1438594
# /mnt/d//data/data_explorer_1Min//osb//platform/osb_platform_ph_1Min.nc 3594181
# /mnt/d//data/data_explorer_1Min//osb//platform/osb_platform_pressure_1Min.nc 3594340
# /mnt/d//data/data_explorer_1Min//osb//platform/osb_platform_salinity_1Min.nc 3594340
# /mnt/d//data/data_explorer_1Min//osb//platform/osb_platform_temperature_1Min.nc 3594340
